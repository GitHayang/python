# %%
# 행과 열을 다루는 라이브러리
import pandas as pd

# %%
# 행과 열이 있는 데이터 불러오기
Customer = pd.read_csv("C:/Users/caose/stdcode6/dataset/kopo_customerdata.csv")
Customer.head(10)
# Out:
#    CUSTOMERCODE STATENAME  ST  GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0       1503989    State2   2    Male    0        1      1         0
# 1       1190338    State2   2    Male    0        1      0         1
# 2       1424715    State2   2  Female    0        2      0         0
# 3       2483305    State2   2    Male    0        1      0         1
# 4       1178802    State2   2    Male    0        1      0         1
# 5        859044    State2   2    Male    0        1      0         0
# 6        734198    State2   2  Female    0        2      0         0
# 7       1443485    State2   2  Female    0        2      0         0
# 8       2340520    State2   2    Male    0        1      0         1
# 9        697949    State2   2    Male    0        1      0         1
#
#    TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  IS_HIGHEND  \
# 0         30300          0      30300          0              0           0
# ...

# %%
Cars = pd.read_csv("../dataset/cars.csv")
Cars.head(10)
# Out:
#    age  gender  miles   debt  income  sales
# 0   28       0     23      0    4099    620
# 1   26       0     27      0    2677   1792
# 2   30       1     58  41576    6215  27754
# 3   26       1     25  43172    7626  28256
# 4   20       1     17   6979    8071   4438
# 5   58       1     18      0    1262   2102
# 6   44       1     17    418    7017   8520
# 7   39       1     28      0    3282    500
# 8   44       0     24  48724    9980  22997
# 9   46       1     46  57827    8163  26517

# %%
std1 = [111,222,333]

# %%
stdDF = pd.DataFrame(std1, columns=['학번'])
stdDF
# Out:
#     학번
# 0  111
# 1  222
# 2  333

# %%
type(stdDF)
# Out:
# pandas.core.frame.DataFrame

# %%
# 칼럼 기준 병합
std2 = ["김효관","백승수","이승철"]

# %%
nameList = pd.DataFrame(std2, columns=['이름'])
nameList
# Out:
#     이름
# 0  김효관
# 1  백승수
# 2  이승철

# %%
finalDF = pd.DataFrame(zip(std1,std2),columns=['학번', '이름'])
finalDF
# Out:
#     학번   이름
# 0  111  김효관
# 1  222  백승수
# 2  333  이승철

# %%
# 열기준 취합
row1List = ["111","홍길동"]
row2List = ["222","이승철"]

# %%
finalDF2 = pd.DataFrame([row1List,row2List],columns=["학번","이름"])
finalDF2
# Out:
#     학번   이름
# 0  111  홍길동
# 1  222  이승철

# %%
finalDF2.to_csv("../dataset/stdDataOut.csv", index = False, encoding="utf-8")
# 한글이 깨질때 encoding = "ms949"
# encoding = "ms949"는 깨진다
# 80~90%는 된다.
#     왤까? 
# 윈도우 euckr -> ms949
# 웹 -> utf-8
# 없던 인덱스가 생겼다 index = False

# %%
pd.read_csv("../dataset/stdDataOut.csv")
# Out:
#     학번   이름
# 0  111  홍길동
# 1  222  이승철

# %%
# 그냥 복사만 해놓으면 알아서 붙여준다
indataClip = pd.read_clipboard("../Session02 - 파이썬 기초 다지기/")
indataClip
# Out:
#     이릅        학번
# 0  백승수  20170139
