# %%
import pandas as pd
import sys
import re

# %% [raw]
# # 시트 2개 받아오고 칼럼 필요없는 줄 2줄 빼고 받아온다

# %%
gyorangData = pd.read_excel("../dataset/calsdata2.xlsx",sheet_name=[0,1] ,skiprows=2)

# %% [raw]
# # 2개의 데이터 프레임 변수에 저장

# %%
gyorangData1 = gyorangData[0]
gyorangData1.shape
# Out:
# (69, 69)

# %%
gyorangData2 = gyorangData[1]
gyorangData2.shape
# Out:
# (355, 82)

# %% [raw]
# # 칼럼 조회

# %%
gyorangData1.columns
# Out:
# Index(['설계사', '프로젝트명', '연도', '실시설계 승인', '교량명', '교량형식', '축척', '총경간장', '경간개수',
#        '1경간', '2경간', '3경간', '4경간', '5경간', '6경간', '7경간', '8경간', '9경간', 'S',
#        'Unnamed: 19', 'L [m]', 'Unnamed: 21', 'H [m]', 'Unnamed: 23', 'K',
#        '1교각 기둥높이', '2교각 기둥높이', '3교각 기둥높이', '4교각 기둥높이 ', '5교각 기둥높이', '6교각 기둥높이',
#        '7교각 기둥높이', '8교각 기둥높이', '축척.1', '폭원', '차로폭(좌)', '차로수(좌)', '차로폭(우)',
#        '차로수(우)', '방호벽(좌)', '방호벽(우)', '보도폭(좌)', '보도폭(우)', '보차도경계석(좌)',
#        '보차도경계석(우)', '길어깨(좌)', '길어깨(우)', '중앙부', '도로포장두께', '바닥슬라브두께', '거더개수',
#        '거더높이', '거더간격', '거더받침높이', '코핑높이(직선+곡선)', '코핑높이(직선부)', '코핑높이(곡선부)',
#        '코핑폭(최대)', '코핑폭(최소)', '기둥형태', '기둥폭', '기초폭', '기초높이', '자전거(좌)', '자전거(우)',
#        '외측길어깨(좌)', '외측길어깨(우)', '내측길어깨(좌)', '내측길어깨(우)'],
#       dtype='object')

# %%
gyorangData2.columns
# Out:
# Index(['설계사', '프로젝트명', '연도', '실시설계 승인', '건설준공', '교량명', '교량형식', '축척', '총경간장',
#        '경간개수', '1경간', '2경간', '3경간', '4경간', '5경간', '6경간', '7경간', '8경간', '9경간',
#        '10경간', '11경간', '12경간', '13경간', '14경간', '15경간', '16경간', 'S',
#        'Unnamed: 27', 'L [m]', 'Unnamed: 29', 'H [m]', 'Unnamed: 31', 'K',
#        '1교각 기둥높이', '2교각 기둥높이', '3교각 기둥높이', '4교각 기둥높이 ', '5교각 기둥높이', '6교각 기둥높이',
#        '7교각 기둥높이', '8교각 기둥높이', '9교각 기둥높이', '10교각 기둥높이', '11교각 기둥높이',
#        '12교각 기둥높이', '13교각 기둥높이', '축척.1', '폭원', '차로폭(좌)', '차로수(좌)', '차로폭(우)',
#        '차로수(우)', '방호벽(좌)', '방호벽(우)', '보도폭(좌)', '보도폭(우)', '보차도경계석(좌)',
#        '보차도경계석(우)', '길어깨(좌)', '길어깨(우)', '중앙부', '도로포장두께', '바닥슬라브두께', '거더개수',
#        '거더높이', '거더간격', '거더받침높이', '코핑높이(직선+곡선)', '코핑높이(직선부)', '코핑높이(곡선부)',
#        '코핑폭(최대)', '코핑폭(최소)', '기둥형태', '기둥폭', '기초폭', '기초높이', '자전거(좌)', '자전거(우)',
#        '외측길어깨(좌)', '외측길어깨(우)', '내측길어깨(좌)', '내측길어깨(우)'],
#       dtype='object')

# %% [raw]
# # 2가지 데이터 프레임 병합

# %%
gyung = pd.concat([gyorangData1,gyorangData2],axis=0)
gyung.head()
# Out:
#        설계사                                프로젝트명    연도  실시설계 승인   교량명 교량형식  \
# 0  극동엔지니어링  번재소류지~백호정사간(대로1-13호선)개설공사 실시설계 보완용역  1차년도  2020.05   소초교  거더교
# 1    도담이앤씨      ○○-△△간 지방도4차로 확·포장공사 실시설계 (2공구)  1차년도  2022.02  △△천교  거더교
# 2   동일기술공사             □□고개 위험도로 개량공사 기본 및 실시설계  1차년도  2022.02  BB교량  라멘교
# 3   한국종합기술                  00 ~ 00 국도건설공사 실시설계  1차년도      NaN   평촌교  거더교
# 4   한국종합기술                  00 ~ 00 국도건설공사 실시설계  1차년도      NaN   금서교  거더교
#
#       축척      총경간장  경간개수      1경간  ...  15경간  16경간  Unnamed: 27  Unnamed: 29  \
# 0  1:500   48135.0   1.0  48135.0  ...   NaN   NaN          NaN          NaN
# 1  1:400  280860.0   8.0  35202.0  ...   NaN   NaN          NaN          NaN
# 2  1:300   15500.0   1.0  15500.0  ...   NaN   NaN          NaN          NaN
# 3  1:300   50148.0   1.0  50148.0  ...   NaN   NaN          NaN          NaN
# 4  1:300   60140.0   2.0  30038.0  ...   NaN   NaN          NaN          NaN
#
# ...

# %% [raw]
# # 숫자로 시작하는 칼럼 변경

# %%
gyung = gyung.rename(columns={"1경간":"경간_1","2경간":"경간_2","3경간":"경간_3","4경간":"경간_4","5경간":"경간_5","6경간":"경간_6","7경간":"경간_7","8경간":"경간_8","9경간":"경간_9","10경간":"경간_10","11경간":"경간_11","12경간":"경간_12","13경간":"경간_13","14경간":"경간_14","15경간":"경간_15","16경간":"경간_16"})
gyung = gyung.rename(columns={"1교각 기둥높이":"교각 기둥높이_1","2교각 기둥높이":"교각 기둥높이_2","3교각 기둥높이":"교각 기둥높이_3","4교각 기둥높이":"교각 기둥높이_4","5교각 기둥높이":"교각 기둥높이_5","6교각 기둥높이":"교각 기둥높이_6","7교각 기둥높이":"교각 기둥높이_7","8교각 기둥높이":"교각 기둥높이_8","9교각 기둥높이":"교각 기둥높이_9","10교각 기둥높이":"교각 기둥높이_10","11교각 기둥높이":"교각 기둥높이_11","12교각 기둥높이":"교각 기둥높이_12","13교각 기둥높이":"교각 기둥높이_13","14교각 기둥높이":"교각 기둥높이_14","15교각 기둥높이":"교각 기둥높이_15","16교각 기둥높이":"교각 기둥높이_16"})
gyung.columns
# Out:
# Index(['설계사', '프로젝트명', '연도', '실시설계 승인', '교량명', '교량형식', '축척', '총경간장', '경간개수',
#        '경간_1', '경간_2', '경간_3', '경간_4', '경간_5', '경간_6', '경간_7', '경간_8', '경간_9',
#        'S', 'Unnamed: 19', 'L [m]', 'Unnamed: 21', 'H [m]', 'Unnamed: 23', 'K',
#        '교각 기둥높이_1', '교각 기둥높이_2', '교각 기둥높이_3', '4교각 기둥높이 ', '교각 기둥높이_5',
#        '교각 기둥높이_6', '교각 기둥높이_7', '교각 기둥높이_8', '축척.1', '폭원', '차로폭(좌)', '차로수(좌)',
#        '차로폭(우)', '차로수(우)', '방호벽(좌)', '방호벽(우)', '보도폭(좌)', '보도폭(우)', '보차도경계석(좌)',
#        '보차도경계석(우)', '길어깨(좌)', '길어깨(우)', '중앙부', '도로포장두께', '바닥슬라브두께', '거더개수',
#        '거더높이', '거더간격', '거더받침높이', '코핑높이(직선+곡선)', '코핑높이(직선부)', '코핑높이(곡선부)',
#        '코핑폭(최대)', '코핑폭(최소)', '기둥형태', '기둥폭', '기초폭', '기초높이', '자전거(좌)', '자전거(우)',
#        '외측길어깨(좌)', '외측길어깨(우)', '내측길어깨(좌)', '내측길어깨(우)', '건설준공', '경간_10',
#        '경간_11', '경간_12', '경간_13', '경간_14', '경간_15', '경간_16', 'Unnamed: 27',
#        'Unnamed: 29', 'Unnamed: 31', '교각 기둥높이_9', '교각 기둥높이_10', '교각 기둥높이_11',
#        '교각 기둥높이_12', '교각 기둥높이_13'],
# ...

# %% [raw]
# # NaN값이 많이 나오는 컬럼을 다른 값들과 연관성이 적다고 판단해 삭제

# %%
gyung = gyung.drop(columns=["교각 기둥높이_11","교각 기둥높이_12","교각 기둥높이_13"])
gyung = gyung.drop(columns=["Unnamed: 19","Unnamed: 21","Unnamed: 23"])

# %%
gyungCol = gyung.columns
gyungCol
# Out:
# Index(['설계사', '프로젝트명', '연도', '실시설계 승인', '교량명', '교량형식', '축척', '총경간장', '경간개수',
#        '경간_1', '경간_2', '경간_3', '경간_4', '경간_5', '경간_6', '경간_7', '경간_8', '경간_9',
#        'S', 'L [m]', 'H [m]', 'K', '교각 기둥높이_1', '교각 기둥높이_2', '교각 기둥높이_3',
#        '4교각 기둥높이 ', '교각 기둥높이_5', '교각 기둥높이_6', '교각 기둥높이_7', '교각 기둥높이_8', '축척.1',
#        '폭원', '차로폭(좌)', '차로수(좌)', '차로폭(우)', '차로수(우)', '방호벽(좌)', '방호벽(우)',
#        '보도폭(좌)', '보도폭(우)', '보차도경계석(좌)', '보차도경계석(우)', '길어깨(좌)', '길어깨(우)', '중앙부',
#        '도로포장두께', '바닥슬라브두께', '거더개수', '거더높이', '거더간격', '거더받침높이', '코핑높이(직선+곡선)',
#        '코핑높이(직선부)', '코핑높이(곡선부)', '코핑폭(최대)', '코핑폭(최소)', '기둥형태', '기둥폭', '기초폭',
#        '기초높이', '자전거(좌)', '자전거(우)', '외측길어깨(좌)', '외측길어깨(우)', '내측길어깨(좌)',
#        '내측길어깨(우)', '건설준공', '경간_10', '경간_11', '경간_12', '경간_13', '경간_14',
#        '경간_15', '경간_16', 'Unnamed: 27', 'Unnamed: 29', 'Unnamed: 31',
#        '교각 기둥높이_9', '교각 기둥높이_10'],
#       dtype='object')

# %%
gyungCol
# Out:
# Index(['설계사', '프로젝트명', '연도', '실시설계 승인', '교량명', '교량형식', '축척', '총경간장', '경간개수',
#        '경간_1', '경간_2', '경간_3', '경간_4', '경간_5', '경간_6', '경간_7', '경간_8', '경간_9',
#        'S', 'L [m]', 'H [m]', 'K', '교각 기둥높이_1', '교각 기둥높이_2', '교각 기둥높이_3',
#        '4교각 기둥높이 ', '교각 기둥높이_5', '교각 기둥높이_6', '교각 기둥높이_7', '교각 기둥높이_8', '축척.1',
#        '폭원', '차로폭(좌)', '차로수(좌)', '차로폭(우)', '차로수(우)', '방호벽(좌)', '방호벽(우)',
#        '보도폭(좌)', '보도폭(우)', '보차도경계석(좌)', '보차도경계석(우)', '길어깨(좌)', '길어깨(우)', '중앙부',
#        '도로포장두께', '바닥슬라브두께', '거더개수', '거더높이', '거더간격', '거더받침높이', '코핑높이(직선+곡선)',
#        '코핑높이(직선부)', '코핑높이(곡선부)', '코핑폭(최대)', '코핑폭(최소)', '기둥형태', '기둥폭', '기초폭',
#        '기초높이', '자전거(좌)', '자전거(우)', '외측길어깨(좌)', '외측길어깨(우)', '내측길어깨(좌)',
#        '내측길어깨(우)', '건설준공', '경간_10', '경간_11', '경간_12', '경간_13', '경간_14',
#        '경간_15', '경간_16', 'Unnamed: 27', 'Unnamed: 29', 'Unnamed: 31',
#        '교각 기둥높이_9', '교각 기둥높이_10'],
#       dtype='object')

# %% [raw]
# # 구하려는 바닥 슬라브 두께에 있는 특수문자 제거

# %%
gyung.loc[gyung['바닥슬라브두께']=='-'] = None

# %%
gyung.columns
# Out:
# Index(['설계사', '프로젝트명', '연도', '실시설계 승인', '교량명', '교량형식', '축척', '총경간장', '경간개수',
#        '경간_1', '경간_2', '경간_3', '경간_4', '경간_5', '경간_6', '경간_7', '경간_8', '경간_9',
#        'S', 'L [m]', 'H [m]', 'K', '교각 기둥높이_1', '교각 기둥높이_2', '교각 기둥높이_3',
#        '4교각 기둥높이 ', '교각 기둥높이_5', '교각 기둥높이_6', '교각 기둥높이_7', '교각 기둥높이_8', '축척.1',
#        '폭원', '차로폭(좌)', '차로수(좌)', '차로폭(우)', '차로수(우)', '방호벽(좌)', '방호벽(우)',
#        '보도폭(좌)', '보도폭(우)', '보차도경계석(좌)', '보차도경계석(우)', '길어깨(좌)', '길어깨(우)', '중앙부',
#        '도로포장두께', '바닥슬라브두께', '거더개수', '거더높이', '거더간격', '거더받침높이', '코핑높이(직선+곡선)',
#        '코핑높이(직선부)', '코핑높이(곡선부)', '코핑폭(최대)', '코핑폭(최소)', '기둥형태', '기둥폭', '기초폭',
#        '기초높이', '자전거(좌)', '자전거(우)', '외측길어깨(좌)', '외측길어깨(우)', '내측길어깨(좌)',
#        '내측길어깨(우)', '건설준공', '경간_10', '경간_11', '경간_12', '경간_13', '경간_14',
#        '경간_15', '경간_16', 'Unnamed: 27', 'Unnamed: 29', 'Unnamed: 31',
#        '교각 기둥높이_9', '교각 기둥높이_10'],
#       dtype='object')

# %%
len(gyung.columns)
# Out:
# 79

# %% [raw]
# #null제거

# %%
Data = gyung.loc[(gyung.바닥슬라브두께.isnull()==False) | ( gyung.바닥슬라브두께.astype(str).str.upper()!="NAN")]
Data
# Out:
#          설계사                                프로젝트명    연도  실시설계 승인   교량명 교량형식  \
# 0    극동엔지니어링  번재소류지~백호정사간(대로1-13호선)개설공사 실시설계 보완용역  1차년도  2020.05   소초교  거더교
# 1      도담이앤씨      ○○-△△간 지방도4차로 확·포장공사 실시설계 (2공구)  1차년도  2022.02  △△천교  거더교
# 2     동일기술공사             □□고개 위험도로 개량공사 기본 및 실시설계  1차년도  2022.02  BB교량  라멘교
# 3     한국종합기술                  00 ~ 00 국도건설공사 실시설계  1차년도      NaN   평촌교  거더교
# 4     한국종합기술                  00 ~ 00 국도건설공사 실시설계  1차년도      NaN   금서교  거더교
# ..       ...                                  ...   ...      ...   ...  ...
# 349      NaN                     67. 흥해-기계2국도건설공사   NaN  2010.09  지가1교  라멘교
# 351      NaN                     67. 흥해-기계2국도건설공사   NaN  2010.09  지가3교  거더교
# 352      NaN                     67. 흥해-기계2국도건설공사   NaN  2010.09  지가4교  라멘교
# 353      NaN                     67. 흥해-기계2국도건설공사   NaN  2010.09  현내천교  라멘교
# 354      NaN                     67. 흥해-기계2국도건설공사   NaN      NaN  화대천교  거더교
#
# ...

# %%
dropData = gyung.loc[(gyung.바닥슬라브두께.isnull()) | ( gyung.바닥슬라브두께.astype(str).str.upper()=="NAN")]
dropData
# Out:
#          설계사                  프로젝트명    연도  실시설계 승인        교량명  교량형식     축척  \
# 8      지유이엔지    D호선(OO ~ △△) 도로개설공사  1차년도  2022.02        BB교   라멘교  1:500
# 17      None                   None  None      NaN       None  None   None
# 30   수성엔지니어링       OO-OO O공구 도로건설사업  2차년도  2021.10        기동교   라멘교  1:300
# 31   수성엔지니어링           OO항 3단계 진입도로  2차년도  2021.12        동해교   거더교  1:600
# 33   수성엔지니어링   국가지원지방도OO호선(OOOO-OO)  2차년도  2021.09        노당교   라멘교  1:200
# ..       ...                    ...   ...      ...        ...   ...    ...
# 340      NaN  64. 화양-적금(4공구) 도로건설공사   NaN  2011.12        여산교   라멘교  1:200
# 341      NaN  64. 화양-적금(4공구) 도로건설공사   NaN  2011.12        요막교   거더교  1:600
# 342      NaN  64. 화양-적금(4공구) 도로건설공사   NaN      NaN       적금대교   아치교    NaN
# 346      NaN       66. 흥해-기계1국도건설공사   NaN      NaN  달전교(자료손실)   NaN    NaN
# 350      NaN       67. 흥해-기계2국도건설공사   NaN  2010.09       지가2교   라멘교  1:400
#
# ...

# %%
gyung.바닥슬라브두께.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 424 entries, 0 to 354
# Series name: 바닥슬라브두께
# Non-Null Count  Dtype
# --------------  -----
# 247 non-null    object
# dtypes: object(1)
# memory usage: 6.6+ KB

# %% [raw]
# # 현재 구하려는 값과 자전거는 상관이 없는지 모든 값에서 NaN이 나오기에 제거

# %%
gyung = gyung.drop(columns=["자전거(좌)","자전거(우)"])

# %%
gyung.corr()
# Out:
#               실시설계 승인      총경간장      경간개수      경간_1      경간_2      경간_3  \
# 실시설계 승인      1.000000  0.065555  0.079782 -0.089629 -0.148577  0.014367
# 총경간장         0.065555  1.000000 -0.003304  0.539190  0.497035  0.576168
# 경간개수         0.079782 -0.003304  1.000000  0.023094 -0.038071  0.193681
# 경간_1        -0.089629  0.539190  0.023094  1.000000  0.845030  0.855255
# 경간_2        -0.148577  0.497035 -0.038071  0.845030  1.000000  0.797199
# 경간_3         0.014367  0.576168  0.193681  0.855255  0.797199  1.000000
# 경간_4        -0.034917  0.533335  0.090785  0.857070  0.966477  0.990909
# 경간_5        -0.071032  0.609329  0.126306  0.834555  0.841310  0.836663
# 경간_6         0.015909  0.695945  0.347647  0.803060  0.838249  0.787581
# 경간_7         0.238432  0.818041  0.505926  0.819587  0.776297  0.674487
# 경간_8        -0.224543  0.753383  0.329495  0.723164  0.893132  0.935793
# 경간_9         0.582943  0.692226  0.093631  0.718345  0.884650  0.898913
# ...

# %% [raw]
# # 교량형식이 거더교인 부분만 표출

# %%
geoder = gyung.loc[gyung.교량형식=="거더교"].reset_index(drop=True)
geoder
# Out:
#          설계사                                프로젝트명    연도  실시설계 승인    교량명 교량형식  \
# 0    극동엔지니어링  번재소류지~백호정사간(대로1-13호선)개설공사 실시설계 보완용역  1차년도  2020.05    소초교  거더교
# 1      도담이앤씨      ○○-△△간 지방도4차로 확·포장공사 실시설계 (2공구)  1차년도  2022.02   △△천교  거더교
# 2     한국종합기술                  00 ~ 00 국도건설공사 실시설계  1차년도      NaN    평촌교  거더교
# 3     한국종합기술                  00 ~ 00 국도건설공사 실시설계  1차년도      NaN    금서교  거더교
# 4    태조엔지니어링                   국도00호선 시설개량사업 가상설계  1차년도  2022.02   말골천교  거더교
# ..       ...                                  ...   ...      ...    ...  ...
# 204      NaN                     66. 흥해-기계1국도건설공사   NaN  2010.09  단구IC교  거더교
# 205      NaN                     66. 흥해-기계1국도건설공사   NaN  2010.09   벽계천교  거더교
# 206      NaN                     66. 흥해-기계1국도건설공사   NaN  2010.09   앞실천교  거더교
# 207      NaN                     67. 흥해-기계2국도건설공사   NaN  2010.09   지가3교  거더교
# 208      NaN                     67. 흥해-기계2국도건설공사   NaN      NaN   화대천교  거더교
#
# ...

# %%
geoCalumns = geoder.columns
geoCalumns
# Out:
# Index(['설계사', '프로젝트명', '연도', '실시설계 승인', '교량명', '교량형식', '축척', '총경간장', '경간개수',
#        '경간_1', '경간_2', '경간_3', '경간_4', '경간_5', '경간_6', '경간_7', '경간_8', '경간_9',
#        'S', 'L [m]', 'H [m]', 'K', '교각 기둥높이_1', '교각 기둥높이_2', '교각 기둥높이_3',
#        '4교각 기둥높이 ', '교각 기둥높이_5', '교각 기둥높이_6', '교각 기둥높이_7', '교각 기둥높이_8', '축척.1',
#        '폭원', '차로폭(좌)', '차로수(좌)', '차로폭(우)', '차로수(우)', '방호벽(좌)', '방호벽(우)',
#        '보도폭(좌)', '보도폭(우)', '보차도경계석(좌)', '보차도경계석(우)', '길어깨(좌)', '길어깨(우)', '중앙부',
#        '도로포장두께', '바닥슬라브두께', '거더개수', '거더높이', '거더간격', '거더받침높이', '코핑높이(직선+곡선)',
#        '코핑높이(직선부)', '코핑높이(곡선부)', '코핑폭(최대)', '코핑폭(최소)', '기둥형태', '기둥폭', '기초폭',
#        '기초높이', '외측길어깨(좌)', '외측길어깨(우)', '내측길어깨(좌)', '내측길어깨(우)', '건설준공', '경간_10',
#        '경간_11', '경간_12', '경간_13', '경간_14', '경간_15', '경간_16', 'Unnamed: 27',
#        'Unnamed: 29', 'Unnamed: 31', '교각 기둥높이_9', '교각 기둥높이_10'],
#       dtype='object')

# %% [raw]
# # 전체 칼럼 숫자형으로 변경, 숫자 데이터가 아니라면 str 유지

# %%
for i in range(0,len(geoCalumns)):
    try:
        geoder[geoCalumns[i]] = geoder[geoCalumns[i]].astype(float)
    except :
        geoder[geoCalumns[i]] = geoder[geoCalumns[i]].astype(str)
geoder.dtypes
# Out:
# 설계사             object
# 프로젝트명           object
# 연도              object
# 실시설계 승인        float64
# 교량명             object
#                 ...
# Unnamed: 27    float64
# Unnamed: 29    float64
# Unnamed: 31    float64
# 교각 기둥높이_9      float64
# 교각 기둥높이_10     float64
# Length: 77, dtype: object

# %%
geoder.loc[(geoder.바닥슬라브두께.isnull()==False) | ( geoder.바닥슬라브두께.astype(str).str.upper()!="NAN")]
# Out:
#          설계사                                프로젝트명    연도  실시설계 승인    교량명 교량형식  \
# 0    극동엔지니어링  번재소류지~백호정사간(대로1-13호선)개설공사 실시설계 보완용역  1차년도  2020.05    소초교  거더교
# 1      도담이앤씨      ○○-△△간 지방도4차로 확·포장공사 실시설계 (2공구)  1차년도  2022.02   △△천교  거더교
# 2     한국종합기술                  00 ~ 00 국도건설공사 실시설계  1차년도      NaN    평촌교  거더교
# 3     한국종합기술                  00 ~ 00 국도건설공사 실시설계  1차년도      NaN    금서교  거더교
# 4    태조엔지니어링                   국도00호선 시설개량사업 가상설계  1차년도  2022.02   말골천교  거더교
# ..       ...                                  ...   ...      ...    ...  ...
# 204      nan                     66. 흥해-기계1국도건설공사   nan  2010.09  단구IC교  거더교
# 205      nan                     66. 흥해-기계1국도건설공사   nan  2010.09   벽계천교  거더교
# 206      nan                     66. 흥해-기계1국도건설공사   nan  2010.09   앞실천교  거더교
# 207      nan                     67. 흥해-기계2국도건설공사   nan  2010.09   지가3교  거더교
# 208      nan                     67. 흥해-기계2국도건설공사   nan      NaN   화대천교  거더교
#
# ...

# %%
geoder.dtypes
# Out:
# 설계사             object
# 프로젝트명           object
# 연도              object
# 실시설계 승인        float64
# 교량명             object
#                 ...
# Unnamed: 27    float64
# Unnamed: 29    float64
# Unnamed: 31    float64
# 교각 기둥높이_9      float64
# 교각 기둥높이_10     float64
# Length: 77, dtype: object

# %%
geoder.corr()
# Out:
#               실시설계 승인      총경간장      경간개수      경간_1      경간_2      경간_3  \
# 실시설계 승인      1.000000  0.174463  0.178044  0.095560 -0.022495  0.091843
# 총경간장         0.174463  1.000000 -0.018145  0.463233  0.559283  0.581445
# 경간개수         0.178044 -0.018145  1.000000 -0.013402 -0.052164  0.167752
# 경간_1         0.095560  0.463233 -0.013402  1.000000  0.892591  0.881893
# 경간_2        -0.022495  0.559283 -0.052164  0.892591  1.000000  0.951047
# 경간_3         0.091843  0.581445  0.167752  0.881893  0.951047  1.000000
# 경간_4        -0.015256  0.571008  0.070310  0.904536  0.981579  0.994365
# 경간_5        -0.042799  0.671210  0.088767  0.926242  0.895370  0.866588
# 경간_6         0.041239  0.706483  0.300874  0.831102  0.920486  0.925623
# 경간_7         0.343540  0.783235  0.359153  0.799888  0.762436  0.779143
# 경간_8        -0.132641  0.724449  0.175383  0.666542  0.871798  0.924992
# 경간_9         0.825308  0.670169 -0.117546  0.684907  0.872663  0.883908
# ...
