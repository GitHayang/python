# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib
matplotlib.rcParams["font.family"] = "Malgun Gothic"
matplotlib.rcParams["font.size"] = 15
matplotlib.rcParams["axes.unicode_minus"] = False

# %% [markdown]
# -----------혈압

# %%
hyulApData = pd.read_csv("./dataset/hyulApData.csv")
hyulApData
# Out:
#      total_count    id                               memb_id  \
# 0            433  8301  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 1            433  8302  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 2            433  8300  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 3            433  8288  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 4            433  8290  52a62c11-7c4f-4912-91c9-ff5c145328cd
# ..           ...   ...                                   ...
# 428          433  7449  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 429          433  7448  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 430          433  7447  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 431          433  7518  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 432          433  7517  52a62c11-7c4f-4912-91c9-ff5c145328cd
#
#              device_desc fullname             get_time  systolic  diastolic  \
# 0        혈압계(HEM-7142T2)      임일균  2023-07-25 15:57:48     141.0       79.0
# 1        혈압계(HEM-7142T2)      임일균  2023-07-25 15:56:39     133.0       79.0
# ...

# %%
plt.figure(figsize=(20,5))
plt.bar(hyulApData.get_time, hyulApData.systolic, label='systolic')
plt.bar(hyulApData.get_time, hyulApData.diastolic, label='diastolic')

# 그래프 제목과 레이블 설정
plt.title('relation of systolic, diastolic')
plt.xlabel('date')
plt.ylabel('target')

# 범례 추가
plt.legend()

# x축 글자 회전
plt.xticks(rotation=90)

# 그래프 표시
plt.show()

# %%
def date(hyulApData):
    hyulApData["date"] = 0
    for i in range(0,len(hyulApData)):
        hyulApData["date"][i] =  hyulApData["get_time"][i][:13]

# %%
date(hyulApData)
# Out:
# C:\Users\WIN\AppData\Local\Temp\ipykernel_26016\3726094976.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hyulApData["date"][i] =  hyulApData["get_time"][i][:13]

# %%
hyulApData["date"]
# Out:
# 0      2023-07-25 15
# 1      2023-07-25 15
# 2      2023-07-25 04
# 3      2023-07-24 15
# 4      2023-07-24 15
#            ...
# 428    2023-04-21 16
# 429    2023-04-21 16
# 430    2023-04-21 16
# 431    2023-04-18 16
# 432    2023-04-18 15
# Name: date, Length: 433, dtype: object

# %%
hyulApData
# Out:
#      total_count    id                               memb_id  \
# 0            433  8301  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 1            433  8302  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 2            433  8300  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 3            433  8288  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 4            433  8290  52a62c11-7c4f-4912-91c9-ff5c145328cd
# ..           ...   ...                                   ...
# 428          433  7449  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 429          433  7448  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 430          433  7447  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 431          433  7518  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 432          433  7517  52a62c11-7c4f-4912-91c9-ff5c145328cd
#
#              device_desc fullname             get_time  systolic  diastolic  \
# 0        혈압계(HEM-7142T2)      임일균  2023-07-25 15:57:48     141.0       79.0
# 1        혈압계(HEM-7142T2)      임일균  2023-07-25 15:56:39     133.0       79.0
# ...

# %%
hyulApData.isnull().sum()
# Out:
# total_count     0
# id              0
# memb_id         0
# device_desc     0
# fullname        0
# get_time        0
# systolic        0
# diastolic       0
# hr             65
# create_dttm     0
# date            0
# dtype: int64

# %%
list(hyulApData)
# Out:
# ['total_count',
#  'id',
#  'memb_id',
#  'device_desc',
#  'fullname',
#  'get_time',
#  'systolic',
#  'diastolic',
#  'hr',
#  'create_dttm',
#  'date']

# %%
HyulApCol = ['get_time', 'systolic', 'diastolic', 'hr', 'create_dttm', 'date']

# %%
tarHyulApData = hyulApData[HyulApCol]
tarHyulApData
# Out:
#                 get_time  systolic  diastolic    hr          create_dttm  \
# 0    2023-07-25 15:57:48     141.0       79.0  64.0  2023-07-25 15:59:31
# 1    2023-07-25 15:56:39     133.0       79.0  66.0  2023-07-25 15:59:31
# 2    2023-07-25 04:47:57     130.0       69.0  51.0  2023-07-25 04:48:46
# 3    2023-07-24 15:26:16     113.0       74.0  53.0  2023-07-24 15:27:10
# 4    2023-07-24 15:25:14     112.0       75.0  52.0  2023-07-24 15:27:10
# ..                   ...       ...        ...   ...                  ...
# 428  2023-04-21 16:40:56     130.0       89.0  78.0  2023-04-21 16:41:00
# 429  2023-04-21 16:38:51     121.0       77.0  71.0  2023-04-21 16:38:53
# 430  2023-04-21 16:37:50     122.0       70.0  75.0  2023-04-21 16:37:53
# 431  2023-04-18 16:46:52     138.0       88.0   NaN  2023-04-25 03:46:18
# 432  2023-04-18 15:22:02     134.0       85.0   NaN  2023-04-25 03:46:18
#
#               date
# 0    2023-07-25 15
# 1    2023-07-25 15
# 2    2023-07-25 04
# ...

# %% [markdown]
# -------혈당

# %%
hyulDangData = pd.read_csv("./dataset/hyulDangData.csv")
hyulDangData
# Out:
#      total_count   id                               memb_id     device_desc  \
# 0            204  439  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
# 1            204  438  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
# 2            204  437  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
# 3            204  435  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
# 4            204  434  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
# ..           ...  ...                                   ...             ...
# 199          204    5  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
# 200          204   67  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
# 201          204   43  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
# 202          204   94  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
# 203          204   69  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
#
# ...

# %%
plt.figure(figsize=(10,5))
plt.bar(hyulDangData.when_eat, hyulDangData.glucosedata)
plt.xlabel("date")
plt.ylabel("glucosedata")
plt.xticks(rotation=90)
plt.show()

# %%
date(hyulDangData)
# Out:
# C:\Users\WIN\AppData\Local\Temp\ipykernel_26016\3726094976.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hyulApData["date"][i] =  hyulApData["get_time"][i][:13]

# %%
list(hyulDangData)
# Out:
# ['total_count',
#  'id',
#  'memb_id',
#  'device_desc',
#  'fullname',
#  'get_time',
#  'glucosedata',
#  'when_eat',
#  'create_dttm',
#  'date']

# %%
hyulDangCol = ['get_time', 'glucosedata', 'when_eat', 'create_dttm', 'date']

# %%
tarHyulDang = hyulDangData[hyulDangCol]
tarHyulDang
# Out:
#                 get_time  glucosedata     when_eat          create_dttm  \
# 0    2023-07-25 22:30:48          100     식사 후 6시간  2023-07-26 00:43:20
# 1    2023-07-25 20:41:32          121     식사 후 5시간  2023-07-25 20:43:32
# 2    2023-07-25 16:02:48          144  공복 (8시간 이상)  2023-07-25 16:03:49
# 3    2023-07-25 03:16:23           96     식사 후 5시간  2023-07-25 03:20:01
# 4    2023-07-25 03:07:02          106     식사 후 5시간  2023-07-25 03:08:05
# ..                   ...          ...          ...                  ...
# 199  2023-04-21 16:48:14          165  공복 (8시간 이상)  2023-06-08 21:28:01
# 200  2023-04-20 21:25:34          114  공복 (8시간 이상)  2023-06-08 21:28:01
# 201  2023-04-19 04:10:35          109  공복 (8시간 이상)  2023-06-08 21:28:01
# 202  2023-04-12 05:04:55          105  공복 (8시간 이상)  2023-06-08 21:28:01
# 203  2023-01-20 06:43:40          126  공복 (8시간 이상)  2023-06-08 21:28:01
#
#               date
# 0    2023-07-25 22
# 1    2023-07-25 20
# 2    2023-07-25 16
# 3    2023-07-25 03
# ...

# %%
tarHyulDang
# Out:
#                 get_time  glucosedata     when_eat          create_dttm  \
# 0    2023-07-25 22:30:48          100     식사 후 6시간  2023-07-26 00:43:20
# 1    2023-07-25 20:41:32          121     식사 후 5시간  2023-07-25 20:43:32
# 2    2023-07-25 16:02:48          144  공복 (8시간 이상)  2023-07-25 16:03:49
# 3    2023-07-25 03:16:23           96     식사 후 5시간  2023-07-25 03:20:01
# 4    2023-07-25 03:07:02          106     식사 후 5시간  2023-07-25 03:08:05
# ..                   ...          ...          ...                  ...
# 199  2023-04-21 16:48:14          165  공복 (8시간 이상)  2023-06-08 21:28:01
# 200  2023-04-20 21:25:34          114  공복 (8시간 이상)  2023-06-08 21:28:01
# 201  2023-04-19 04:10:35          109  공복 (8시간 이상)  2023-06-08 21:28:01
# 202  2023-04-12 05:04:55          105  공복 (8시간 이상)  2023-06-08 21:28:01
# 203  2023-01-20 06:43:40          126  공복 (8시간 이상)  2023-06-08 21:28:01
#
#               date
# 0    2023-07-25 22
# 1    2023-07-25 20
# 2    2023-07-25 16
# 3    2023-07-25 03
# ...

# %%
tarHyulApData
# Out:
#                 get_time  systolic  diastolic    hr          create_dttm  \
# 0    2023-07-25 15:57:48     141.0       79.0  64.0  2023-07-25 15:59:31
# 1    2023-07-25 15:56:39     133.0       79.0  66.0  2023-07-25 15:59:31
# 2    2023-07-25 04:47:57     130.0       69.0  51.0  2023-07-25 04:48:46
# 3    2023-07-24 15:26:16     113.0       74.0  53.0  2023-07-24 15:27:10
# 4    2023-07-24 15:25:14     112.0       75.0  52.0  2023-07-24 15:27:10
# ..                   ...       ...        ...   ...                  ...
# 428  2023-04-21 16:40:56     130.0       89.0  78.0  2023-04-21 16:41:00
# 429  2023-04-21 16:38:51     121.0       77.0  71.0  2023-04-21 16:38:53
# 430  2023-04-21 16:37:50     122.0       70.0  75.0  2023-04-21 16:37:53
# 431  2023-04-18 16:46:52     138.0       88.0   NaN  2023-04-25 03:46:18
# 432  2023-04-18 15:22:02     134.0       85.0   NaN  2023-04-25 03:46:18
#
#               date
# 0    2023-07-25 15
# 1    2023-07-25 15
# 2    2023-07-25 04
# ...

# %%
#어느 한쪽에만 있는 것이 아닌 양쪽에 모두 있는 데이터

# %%
mergedData = pd.merge(left = tarHyulApData, right = tarHyulDang, on = 'date', how='inner')
mergedData
# Out:
#               get_time_x  systolic  diastolic    hr        create_dttm_x  \
# 0    2023-07-24 15:26:16     113.0       74.0  53.0  2023-07-24 15:27:10
# 1    2023-07-24 15:26:16     113.0       74.0  53.0  2023-07-24 15:27:10
# 2    2023-07-24 15:26:16     113.0       74.0  53.0  2023-07-24 15:27:10
# 3    2023-07-24 15:26:16     113.0       74.0  53.0  2023-07-24 15:27:10
# 4    2023-07-24 15:25:14     112.0       75.0  52.0  2023-07-24 15:27:10
# ..                   ...       ...        ...   ...                  ...
# 320  2023-04-21 16:42:41     137.0       84.0   NaN  2023-04-27 22:52:26
# 321  2023-04-21 16:41:49     118.0       83.0  76.0  2023-04-21 16:41:55
# 322  2023-04-21 16:40:56     130.0       89.0  78.0  2023-04-21 16:41:00
# 323  2023-04-21 16:38:51     121.0       77.0  71.0  2023-04-21 16:38:53
# 324  2023-04-21 16:37:50     122.0       70.0  75.0  2023-04-21 16:37:53
#
#               date           get_time_y  glucosedata     when_eat  \
# ...

# %%
mergedData = mergedData.drop_duplicates()

# %%
mergedData['when_eat'].unique()
# Out:
# array(['공복 (8시간 이상)', '식사 후 7시간', '식사 후 4시간', '식사 후 1시간', '식사 후 3시간',
#        '식사 후 6시간', '식사 후 8시간', '식사 후 2시간', '식사 후 5시간'], dtype=object)

# %%
# 당뇨의 경우 공복기 혈당으로 측정

# %%
# 데이터 상에는 측정시간 : 공복(8시간 이상)이 있지만, 구별없이 되어 있을 경우 시간 구분없이 가져온다.
try:
    eightData = mergedData.loc[mergedData['when_eat'] == "공복 (8시간 이상)"]
    eightData = eightData.reset_index(drop=True)
    eightData
except:
    eightData = mergedData.copy()
eightData
# Out:
#               get_time_x  systolic  diastolic    hr        create_dttm_x  \
# 0    2023-07-24 15:26:16     113.0       74.0  53.0  2023-07-24 15:27:10
# 1    2023-07-24 15:26:16     113.0       74.0  53.0  2023-07-24 15:27:10
# 2    2023-07-24 15:25:14     112.0       75.0  52.0  2023-07-24 15:27:10
# 3    2023-07-24 15:25:14     112.0       75.0  52.0  2023-07-24 15:27:10
# 4    2023-07-24 15:24:18     111.0       68.0  50.0  2023-07-24 15:27:10
# ..                   ...       ...        ...   ...                  ...
# 248  2023-04-21 16:42:41     137.0       84.0   NaN  2023-04-27 22:52:26
# 249  2023-04-21 16:41:49     118.0       83.0  76.0  2023-04-21 16:41:55
# 250  2023-04-21 16:40:56     130.0       89.0  78.0  2023-04-21 16:41:00
# 251  2023-04-21 16:38:51     121.0       77.0  71.0  2023-04-21 16:38:53
# 252  2023-04-21 16:37:50     122.0       70.0  75.0  2023-04-21 16:37:53
#
#               date           get_time_y  glucosedata     when_eat  \
# ...

# %%
eightData.shape
# Out:
# (253, 10)

# %%
eightData.isnull().sum()
# Out:
# get_time_x        0
# systolic          0
# diastolic         0
# hr               16
# create_dttm_x     0
# date              0
# get_time_y        0
# glucosedata       0
# when_eat          0
# create_dttm_y     0
# dtype: int64

# %%
# 16건의 심박 데이터 제거 및 중복값 제거 후 index 정리
eightData = eightData.dropna(axis=0)
eightData = eightData.drop_duplicates()
eightData = eightData.reset_index(drop=True)
eightData
# Out:
#               get_time_x  systolic  diastolic    hr        create_dttm_x  \
# 0    2023-07-24 15:26:16     113.0       74.0  53.0  2023-07-24 15:27:10
# 1    2023-07-24 15:26:16     113.0       74.0  53.0  2023-07-24 15:27:10
# 2    2023-07-24 15:25:14     112.0       75.0  52.0  2023-07-24 15:27:10
# 3    2023-07-24 15:25:14     112.0       75.0  52.0  2023-07-24 15:27:10
# 4    2023-07-24 15:24:18     111.0       68.0  50.0  2023-07-24 15:27:10
# ..                   ...       ...        ...   ...                  ...
# 232  2023-04-22 01:59:48     114.0       77.0  63.0  2023-04-22 01:59:52
# 233  2023-04-21 16:41:49     118.0       83.0  76.0  2023-04-21 16:41:55
# 234  2023-04-21 16:40:56     130.0       89.0  78.0  2023-04-21 16:41:00
# 235  2023-04-21 16:38:51     121.0       77.0  71.0  2023-04-21 16:38:53
# 236  2023-04-21 16:37:50     122.0       70.0  75.0  2023-04-21 16:37:53
#
#               date           get_time_y  glucosedata     when_eat  \
# ...

# %%
eightData.shape
# Out:
# (237, 10)

# %%
eightData.isnull().sum()
# Out:
# get_time_x       0
# systolic         0
# diastolic        0
# hr               0
# create_dttm_x    0
# date             0
# get_time_y       0
# glucosedata      0
# when_eat         0
# create_dttm_y    0
# dtype: int64

# %%
# 날짜별 혈압, 혈당을 시각화

# %%
plt.figure(figsize=(20,5))
plt.bar(eightData.date, eightData.glucosedata)
plt.xticks(rotation=90)
plt.xlabel('date')
plt.ylabel('glucosedata')
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.bar(eightData.date, eightData.systolic)
plt.xticks(rotation=90)
plt.xlabel('date')
plt.ylabel('systolic')
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.bar(eightData.date, eightData.systolic, label = "systolic")
plt.bar(eightData.date, eightData.glucosedata, label = "glucosedata")
plt.xticks(rotation=90)
plt.legend(ncol=4)
plt.show()

# %%
list(eightData)
# Out:
# ['get_time_x',
#  'systolic',
#  'diastolic',
#  'hr',
#  'create_dttm_x',
#  'date',
#  'get_time_y',
#  'glucosedata',
#  'when_eat',
#  'create_dttm_y']

# %%
# 머신에 학습 시켜준 데이터만으로 판단해야하기에 대상 컬럼 추출

# %%
try:
    learnData = eightData[['systolic', 'glucosedata']]
    learnData = learnData.reset_index(drop=True)
except:
    try: # glucosedata가 없을때 
        learnData = eightData[['systolic']]
        learnData['glucosedata'] = 0
        learnData = learnData.reset_index(drop=True)
    except: # systolic이 없을때
        learnData = eightData[['glucosedata']]
        learnData['systolic'] = 0        
        learnData = learnData.reset_index(drop=True)        
learnData
# Out:
#      systolic  glucosedata
# 0       113.0          131
# 1       113.0          120
# 2       112.0          131
# 3       112.0          120
# 4       111.0          131
# ..        ...          ...
# 232     114.0           94
# 233     118.0          165
# 234     130.0          165
# 235     121.0          165
# 236     122.0          165
#
# [237 rows x 2 columns]

# %%
learnData.dtypes
# Out:
# systolic       float64
# glucosedata      int64
# dtype: object

# %%
#모델 불러오기

# %%
import pickle

with open("./hyulApDang.pickle", "rb") as fr:
    loaded_model = pickle.load(fr)

# %%
# 모델을 이용해 측정값들의 건강 상태를 분석
status = []
for i in range(0,len(learnData)):
    pred = pd.DataFrame(learnData.iloc[i])
    transposed_df = pred.transpose()
    transposed_df = transposed_df.rename(columns={"systolic":"SBP","glucosedata":"FBS"})
    status.append(loaded_model.predict(transposed_df))
status = pd.DataFrame(status, columns=["status"])
status
# Out:
#      status
# 0         3
# 1         4
# 2         3
# 3         4
# 4         4
# ..      ...
# 232       4
# 233       3
# 234       1
# 235       3
# 236       3
#
# [237 rows x 1 columns]

# %%
resultData = pd.concat([learnData, status], axis=1)
resultData
# Out:
#      systolic  glucosedata  status
# 0       113.0          131       3
# 1       113.0          120       4
# 2       112.0          131       3
# 3       112.0          120       4
# 4       111.0          131       4
# ..        ...          ...     ...
# 232     114.0           94       4
# 233     118.0          165       3
# 234     130.0          165       1
# 235     121.0          165       3
# 236     122.0          165       3
#
# [237 rows x 3 columns]

# %%
resultData["result"] = ""
resultData["result"] = np.where(resultData["status"] == 1, "고혈압 + 당뇨",
                               np.where(resultData["status"] == 2, "고혈압", 
                                       np.where(resultData["status"] == 3, "당뇨", "건강")))
resultData
# Out:
#      systolic  glucosedata  status    result
# 0       113.0          131       3        당뇨
# 1       113.0          120       4        건강
# 2       112.0          131       3        당뇨
# 3       112.0          120       4        건강
# 4       111.0          131       4        건강
# ..        ...          ...     ...       ...
# 232     114.0           94       4        건강
# 233     118.0          165       3        당뇨
# 234     130.0          165       1  고혈압 + 당뇨
# 235     121.0          165       3        당뇨
# 236     122.0          165       3        당뇨
#
# [237 rows x 4 columns]

# %%
resultData = pd.concat([eightData.date, resultData], axis=1)
resultData
# Out:
#               date  systolic  glucosedata  status    result
# 0    2023-07-24 15     113.0          131       3        당뇨
# 1    2023-07-24 15     113.0          120       4        건강
# 2    2023-07-24 15     112.0          131       3        당뇨
# 3    2023-07-24 15     112.0          120       4        건강
# 4    2023-07-24 15     111.0          131       4        건강
# ..             ...       ...          ...     ...       ...
# 232  2023-04-22 01     114.0           94       4        건강
# 233  2023-04-21 16     118.0          165       3        당뇨
# 234  2023-04-21 16     130.0          165       1  고혈압 + 당뇨
# 235  2023-04-21 16     121.0          165       3        당뇨
# 236  2023-04-21 16     122.0          165       3        당뇨
#
# [237 rows x 5 columns]

# %%
# 건강 상태에 대한 백분율

# %%
status_counts = resultData['result'].value_counts()

plt.bar(status_counts.index, status_counts.values)

plt.xlabel('건강 상태')
plt.ylabel('Count')

plt.xticks(status_counts.index, rotation=45)

plt.show()

# %%
import matplotlib.pyplot as plt
status_counts = resultData['result'].value_counts()
status_percentages = (status_counts / len(resultData)) * 100
explode = [0.05]*4
plt.pie(status_percentages, labels=status_counts.index, autopct='%1.1f%%', explode=explode)
plt.title('건강 상태')
plt.show()

# %%
total = (status_counts[0]+status_counts[1]+status_counts[2]+status_counts[3])
diabetes = (status_counts[1]+status_counts[2])/total
hypertension = (status_counts[1]+status_counts[3])/total

print("당뇨(%) : ", diabetes)
print("고혈압(%) : ", hypertension)
# Out:
# 당뇨(%) :  0.4008438818565401
# 고혈압(%) :  0.25316455696202533

# %% [raw]
# # test용
# diabetes = 0.2
# hypertension = 0.1

# %%
if diabetes >= 0.3 or hypertension >= 0.3:
    # 당뇨
    if diabetes >= 0.3 and diabetes < 0.4:
        print("당뇨 주의")
    elif diabetes >= 0.4:
        print("당뇨 위험")
    else:
        pass

    # 고혈압
    if hypertension >= 0.3 and hypertension < 0.4:
        print("고혈압 주의")
    elif hypertension >= 0.4:
        print("고혈압 위험")
    else:
        pass
else : 
    print("건강합니다.")
# Out:
# 당뇨 위험

# %% [raw]
# 개선점
# 1. 입력받은 파일을 DB에 저장하고 같은 사람의 데이터일 경우 계속 추가하여 개선되었는지 확인할 수 있는 기능추가
# 2. 혈당은 공복 기준으로 재는 것으로 나오는데, 기록시간이 공복이 아닐경우의 측정법
# 3.
