# %%
import pandas as pd
import numpy as np

# %% [markdown]
# -----------혈압

# %%
hyulApData = pd.read_csv("./dataset/hyulApData.csv")
hyulApData
# Out:
#      total_count    id                               memb_id  \
# 0            433  8301  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 1            433  8302  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 2            433  8300  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 3            433  8288  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 4            433  8290  52a62c11-7c4f-4912-91c9-ff5c145328cd
# ..           ...   ...                                   ...
# 428          433  7449  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 429          433  7448  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 430          433  7447  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 431          433  7518  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 432          433  7517  52a62c11-7c4f-4912-91c9-ff5c145328cd
#
#              device_desc fullname             get_time  systolic  diastolic  \
# 0        혈압계(HEM-7142T2)      임일균  2023-07-25 15:57:48     141.0       79.0
# 1        혈압계(HEM-7142T2)      임일균  2023-07-25 15:56:39     133.0       79.0
# ...

# %%
def date(hyulApData):
    hyulApData["date"] = 0
    for i in range(0,len(hyulApData)):
        hyulApData["date"][i] =  hyulApData["get_time"][i][:13]

# %%
date(hyulApData)
# Out:
# C:\Users\WIN\AppData\Local\Temp\ipykernel_24228\3726094976.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hyulApData["date"][i] =  hyulApData["get_time"][i][:13]

# %%
hyulApData["date"]
# Out:
# 0      2023-07-25 15
# 1      2023-07-25 15
# 2      2023-07-25 04
# 3      2023-07-24 15
# 4      2023-07-24 15
#            ...
# 428    2023-04-21 16
# 429    2023-04-21 16
# 430    2023-04-21 16
# 431    2023-04-18 16
# 432    2023-04-18 15
# Name: date, Length: 433, dtype: object

# %%
hyulApData
# Out:
#      total_count    id                               memb_id  \
# 0            433  8301  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 1            433  8302  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 2            433  8300  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 3            433  8288  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 4            433  8290  52a62c11-7c4f-4912-91c9-ff5c145328cd
# ..           ...   ...                                   ...
# 428          433  7449  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 429          433  7448  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 430          433  7447  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 431          433  7518  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 432          433  7517  52a62c11-7c4f-4912-91c9-ff5c145328cd
#
#              device_desc fullname             get_time  systolic  diastolic  \
# 0        혈압계(HEM-7142T2)      임일균  2023-07-25 15:57:48     141.0       79.0
# 1        혈압계(HEM-7142T2)      임일균  2023-07-25 15:56:39     133.0       79.0
# ...

# %%
hyulApData.isnull().sum()
# Out:
# total_count     0
# id              0
# memb_id         0
# device_desc     0
# fullname        0
# get_time        0
# systolic        0
# diastolic       0
# hr             65
# create_dttm     0
# date            0
# dtype: int64

# %%
list(hyulApData)
# Out:
# ['total_count',
#  'id',
#  'memb_id',
#  'device_desc',
#  'fullname',
#  'get_time',
#  'systolic',
#  'diastolic',
#  'hr',
#  'create_dttm',
#  'date']

# %%
HyulApCol = ['systolic', 'diastolic', 'hr', 'date']

# %%
tarHyulApData = hyulApData[HyulApCol]
tarHyulApData
# Out:
#      systolic  diastolic    hr           date
# 0       141.0       79.0  64.0  2023-07-25 15
# 1       133.0       79.0  66.0  2023-07-25 15
# 2       130.0       69.0  51.0  2023-07-25 04
# 3       113.0       74.0  53.0  2023-07-24 15
# 4       112.0       75.0  52.0  2023-07-24 15
# ..        ...        ...   ...            ...
# 428     130.0       89.0  78.0  2023-04-21 16
# 429     121.0       77.0  71.0  2023-04-21 16
# 430     122.0       70.0  75.0  2023-04-21 16
# 431     138.0       88.0   NaN  2023-04-18 16
# 432     134.0       85.0   NaN  2023-04-18 15
#
# [433 rows x 4 columns]

# %% [markdown]
# -------혈당

# %%
hyulDangData = pd.read_csv("./dataset/hyulDangData.csv")
hyulDangData
# Out:
#      total_count   id                               memb_id     device_desc  \
# 0            204  439  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
# 1            204  438  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
# 2            204  437  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
# 3            204  435  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
# 4            204  434  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
# ..           ...  ...                                   ...             ...
# 199          204    5  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
# 200          204   67  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
# 201          204   43  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
# 202          204   94  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
# 203          204   69  52a62c11-7c4f-4912-91c9-ff5c145328cd  혈당계(N Premier)
#
# ...

# %%
date(hyulDangData)
# Out:
# C:\Users\WIN\AppData\Local\Temp\ipykernel_24228\3726094976.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hyulApData["date"][i] =  hyulApData["get_time"][i][:13]

# %%
list(hyulDangData)
# Out:
# ['total_count',
#  'id',
#  'memb_id',
#  'device_desc',
#  'fullname',
#  'get_time',
#  'glucosedata',
#  'when_eat',
#  'create_dttm',
#  'date']

# %%
hyulDangCol = ['glucosedata', 'when_eat', 'date']

# %%
tarHyulDang = hyulDangData[hyulDangCol]
tarHyulDang
# Out:
#      glucosedata     when_eat           date
# 0            100     식사 후 6시간  2023-07-25 22
# 1            121     식사 후 5시간  2023-07-25 20
# 2            144  공복 (8시간 이상)  2023-07-25 16
# 3             96     식사 후 5시간  2023-07-25 03
# 4            106     식사 후 5시간  2023-07-25 03
# ..           ...          ...            ...
# 199          165  공복 (8시간 이상)  2023-04-21 16
# 200          114  공복 (8시간 이상)  2023-04-20 21
# 201          109  공복 (8시간 이상)  2023-04-19 04
# 202          105  공복 (8시간 이상)  2023-04-12 05
# 203          126  공복 (8시간 이상)  2023-01-20 06
#
# [204 rows x 3 columns]

# %% [markdown]
# -------산소포화도

# %%
sansopohwadoData = pd.read_csv("./dataset/sansopohwadoData.csv")
sansopohwadoData
# Out:
#     total_count    id                               memb_id  \
# 0            93  7699  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 1            93  7698  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 2            93  7694  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 3            93  7693  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 4            93  7691  52a62c11-7c4f-4912-91c9-ff5c145328cd
# ..          ...   ...                                   ...
# 88           93  7482  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 89           93  7477  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 90           93  7476  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 91           93  7470  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 92           93  7466  52a62c11-7c4f-4912-91c9-ff5c145328cd
#
#             device_desc fullname             get_time  spo2  heart_rate  \
# 0   갤럭시워치(Galaxy Watch)      임일균  2023-07-25 02:25:52    95          68
# 1   갤럭시워치(Galaxy Watch)      임일균  2023-07-24 15:37:53    96          55
# ...

# %%
date(sansopohwadoData)
# Out:
# C:\Users\WIN\AppData\Local\Temp\ipykernel_24228\3726094976.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hyulApData["date"][i] =  hyulApData["get_time"][i][:13]

# %%
sansopohwadoData
# Out:
#     total_count    id                               memb_id  \
# 0            93  7699  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 1            93  7698  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 2            93  7694  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 3            93  7693  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 4            93  7691  52a62c11-7c4f-4912-91c9-ff5c145328cd
# ..          ...   ...                                   ...
# 88           93  7482  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 89           93  7477  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 90           93  7476  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 91           93  7470  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 92           93  7466  52a62c11-7c4f-4912-91c9-ff5c145328cd
#
#             device_desc fullname             get_time  spo2  heart_rate  \
# 0   갤럭시워치(Galaxy Watch)      임일균  2023-07-25 02:25:52    95          68
# 1   갤럭시워치(Galaxy Watch)      임일균  2023-07-24 15:37:53    96          55
# ...

# %%
list(sansopohwadoData)
# Out:
# ['total_count',
#  'id',
#  'memb_id',
#  'device_desc',
#  'fullname',
#  'get_time',
#  'spo2',
#  'heart_rate',
#  'create_dttm',
#  'date']

# %%
sansopohwadoCol = ['spo2', 'heart_rate', 'date']

# %%
tarSansopohwado = sansopohwadoData[sansopohwadoCol]
tarSansopohwado
# Out:
#     spo2  heart_rate           date
# 0     95          68  2023-07-25 02
# 1     96          55  2023-07-24 15
# 2     96          64  2023-07-22 03
# 3     94          77  2023-07-22 01
# 4     85          64  2023-07-21 04
# ..   ...         ...            ...
# 88    96          57  2023-04-24 22
# 89    96          61  2023-04-23 21
# 90    90          60  2023-04-23 21
# 91    96          64  2023-04-21 20
# 92    94          79  2023-04-21 16
#
# [93 rows x 3 columns]

# %% [markdown]
# --------심박수

# %%
simbaksuData = pd.read_csv("./dataset/simbaksuData.csv")
simbaksuData
# Out:
#      total_count    id                               memb_id  \
# 0            120  9771  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 1            120  9770  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 2            120  9769  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 3            120  9765  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 4            120  9764  52a62c11-7c4f-4912-91c9-ff5c145328cd
# ..           ...   ...                                   ...
# 115          120  9382  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 116          120  9381  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 117          120  9379  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 118          120  9373  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 119          120  9369  52a62c11-7c4f-4912-91c9-ff5c145328cd
#
#              device_desc fullname             get_time  heart_rate  \
# 0    갤럭시워치(Galaxy Watch)      임일균  2023-07-25 02:24:51          69
# 1    갤럭시워치(Galaxy Watch)      임일균  2023-07-24 15:42:09          58
# ...

# %%
date(simbaksuData)
# Out:
# C:\Users\WIN\AppData\Local\Temp\ipykernel_24228\3726094976.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hyulApData["date"][i] =  hyulApData["get_time"][i][:13]

# %%
simbaksuData
# Out:
#      total_count    id                               memb_id  \
# 0            120  9771  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 1            120  9770  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 2            120  9769  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 3            120  9765  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 4            120  9764  52a62c11-7c4f-4912-91c9-ff5c145328cd
# ..           ...   ...                                   ...
# 115          120  9382  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 116          120  9381  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 117          120  9379  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 118          120  9373  52a62c11-7c4f-4912-91c9-ff5c145328cd
# 119          120  9369  52a62c11-7c4f-4912-91c9-ff5c145328cd
#
#              device_desc fullname             get_time  heart_rate  \
# 0    갤럭시워치(Galaxy Watch)      임일균  2023-07-25 02:24:51          69
# 1    갤럭시워치(Galaxy Watch)      임일균  2023-07-24 15:42:09          58
# ...

# %%
list(simbaksuData)
# Out:
# ['total_count',
#  'id',
#  'memb_id',
#  'device_desc',
#  'fullname',
#  'get_time',
#  'heart_rate',
#  'create_dttm',
#  'date']

# %%
simbaksuCol = ['heart_rate', 'date']

# %%
tarSimbaksu = simbaksuData[simbaksuCol]
tarSimbaksu
# Out:
#      heart_rate           date
# 0            69  2023-07-25 02
# 1            58  2023-07-24 15
# 2            55  2023-07-24 15
# 3            62  2023-07-22 10
# 4            60  2023-07-22 03
# ..          ...            ...
# 115          64  2023-04-23 21
# 116          69  2023-04-22 20
# 117          74  2023-04-22 02
# 118          62  2023-04-21 20
# 119          77  2023-04-21 16
#
# [120 rows x 2 columns]

# %%
tarHyulDang
# Out:
#      glucosedata     when_eat           date
# 0            100     식사 후 6시간  2023-07-25 22
# 1            121     식사 후 5시간  2023-07-25 20
# 2            144  공복 (8시간 이상)  2023-07-25 16
# 3             96     식사 후 5시간  2023-07-25 03
# 4            106     식사 후 5시간  2023-07-25 03
# ..           ...          ...            ...
# 199          165  공복 (8시간 이상)  2023-04-21 16
# 200          114  공복 (8시간 이상)  2023-04-20 21
# 201          109  공복 (8시간 이상)  2023-04-19 04
# 202          105  공복 (8시간 이상)  2023-04-12 05
# 203          126  공복 (8시간 이상)  2023-01-20 06
#
# [204 rows x 3 columns]

# %%
tarHyulApData
# Out:
#      systolic  diastolic    hr           date
# 0       141.0       79.0  64.0  2023-07-25 15
# 1       133.0       79.0  66.0  2023-07-25 15
# 2       130.0       69.0  51.0  2023-07-25 04
# 3       113.0       74.0  53.0  2023-07-24 15
# 4       112.0       75.0  52.0  2023-07-24 15
# ..        ...        ...   ...            ...
# 428     130.0       89.0  78.0  2023-04-21 16
# 429     121.0       77.0  71.0  2023-04-21 16
# 430     122.0       70.0  75.0  2023-04-21 16
# 431     138.0       88.0   NaN  2023-04-18 16
# 432     134.0       85.0   NaN  2023-04-18 15
#
# [433 rows x 4 columns]

# %%
tarSansopohwado
# Out:
#     spo2  heart_rate           date
# 0     95          68  2023-07-25 02
# 1     96          55  2023-07-24 15
# 2     96          64  2023-07-22 03
# 3     94          77  2023-07-22 01
# 4     85          64  2023-07-21 04
# ..   ...         ...            ...
# 88    96          57  2023-04-24 22
# 89    96          61  2023-04-23 21
# 90    90          60  2023-04-23 21
# 91    96          64  2023-04-21 20
# 92    94          79  2023-04-21 16
#
# [93 rows x 3 columns]

# %%
tarSimbaksu
# Out:
#      heart_rate           date
# 0            69  2023-07-25 02
# 1            58  2023-07-24 15
# 2            55  2023-07-24 15
# 3            62  2023-07-22 10
# 4            60  2023-07-22 03
# ..          ...            ...
# 115          64  2023-04-23 21
# 116          69  2023-04-22 20
# 117          74  2023-04-22 02
# 118          62  2023-04-21 20
# 119          77  2023-04-21 16
#
# [120 rows x 2 columns]

# %%
#어느 한쪽에만 있는 것이 아닌 양쪽에 모두 있는 데이터

# %%
dangAp = pd.merge(left = tarHyulApData, right = tarHyulDang, on = 'date', how='inner')
dangAp
# Out:
#      systolic  diastolic    hr           date  glucosedata     when_eat
# 0       113.0       74.0  53.0  2023-07-24 15          131  공복 (8시간 이상)
# 1       113.0       74.0  53.0  2023-07-24 15          130     식사 후 7시간
# 2       113.0       74.0  53.0  2023-07-24 15          120  공복 (8시간 이상)
# 3       113.0       74.0  53.0  2023-07-24 15          128     식사 후 4시간
# 4       112.0       75.0  52.0  2023-07-24 15          131  공복 (8시간 이상)
# ..        ...        ...   ...            ...          ...          ...
# 320     137.0       84.0   NaN  2023-04-21 16          165  공복 (8시간 이상)
# 321     118.0       83.0  76.0  2023-04-21 16          165  공복 (8시간 이상)
# 322     130.0       89.0  78.0  2023-04-21 16          165  공복 (8시간 이상)
# 323     121.0       77.0  71.0  2023-04-21 16          165  공복 (8시간 이상)
# 324     122.0       70.0  75.0  2023-04-21 16          165  공복 (8시간 이상)
#
# [325 rows x 6 columns]

# %%
sansoSimbak = pd.merge(left = tarSansopohwado, right = tarSimbaksu, on = 'date', how='inner')
sansoSimbak
# Out:
#     spo2  heart_rate_x           date  heart_rate_y
# 0     95            68  2023-07-25 02            69
# 1     96            55  2023-07-24 15            58
# 2     96            55  2023-07-24 15            55
# 3     96            64  2023-07-22 03            60
# 4     94            77  2023-07-22 01            84
# ..   ...           ...            ...           ...
# 93    96            57  2023-04-24 22            65
# 94    96            61  2023-04-23 21            64
# 95    90            60  2023-04-23 21            64
# 96    96            64  2023-04-21 20            62
# 97    94            79  2023-04-21 16            77
#
# [98 rows x 4 columns]

# %%
mergedData = pd.merge(left = dangAp, right = sansoSimbak, on = 'date', how='inner')
mergedData
# Out:
#      systolic  diastolic    hr           date  glucosedata     when_eat  spo2  \
# 0       113.0       74.0  53.0  2023-07-24 15          131  공복 (8시간 이상)    96
# 1       113.0       74.0  53.0  2023-07-24 15          131  공복 (8시간 이상)    96
# 2       113.0       74.0  53.0  2023-07-24 15          130     식사 후 7시간    96
# 3       113.0       74.0  53.0  2023-07-24 15          130     식사 후 7시간    96
# 4       113.0       74.0  53.0  2023-07-24 15          120  공복 (8시간 이상)    96
# ..        ...        ...   ...            ...          ...          ...   ...
# 148     137.0       84.0   NaN  2023-04-21 16          165  공복 (8시간 이상)    94
# 149     118.0       83.0  76.0  2023-04-21 16          165  공복 (8시간 이상)    94
# 150     130.0       89.0  78.0  2023-04-21 16          165  공복 (8시간 이상)    94
# 151     121.0       77.0  71.0  2023-04-21 16          165  공복 (8시간 이상)    94
# 152     122.0       70.0  75.0  2023-04-21 16          165  공복 (8시간 이상)    94
#
#      heart_rate_x  heart_rate_y
# ...

# %%
mergedData = mergedData.drop_duplicates()

# %%
mergedData['when_eat'].unique()
# Out:
# array(['공복 (8시간 이상)', '식사 후 7시간', '식사 후 4시간', '식사 후 3시간', '식사 후 2시간'],
#       dtype=object)

# %%
eightData = mergedData.loc[mergedData['when_eat'] == "공복 (8시간 이상)"]
eightData
# Out:
#      systolic  diastolic    hr           date  glucosedata     when_eat  spo2  \
# 0       113.0       74.0  53.0  2023-07-24 15          131  공복 (8시간 이상)    96
# 1       113.0       74.0  53.0  2023-07-24 15          131  공복 (8시간 이상)    96
# 4       113.0       74.0  53.0  2023-07-24 15          120  공복 (8시간 이상)    96
# 5       113.0       74.0  53.0  2023-07-24 15          120  공복 (8시간 이상)    96
# 8       112.0       75.0  52.0  2023-07-24 15          131  공복 (8시간 이상)    96
# ..        ...        ...   ...            ...          ...          ...   ...
# 148     137.0       84.0   NaN  2023-04-21 16          165  공복 (8시간 이상)    94
# 149     118.0       83.0  76.0  2023-04-21 16          165  공복 (8시간 이상)    94
# 150     130.0       89.0  78.0  2023-04-21 16          165  공복 (8시간 이상)    94
# 151     121.0       77.0  71.0  2023-04-21 16          165  공복 (8시간 이상)    94
# 152     122.0       70.0  75.0  2023-04-21 16          165  공복 (8시간 이상)    94
#
#      heart_rate_x  heart_rate_y
# ...

# %%
afterSeven = mergedData.loc[mergedData['when_eat'] == '식사 후 7시간']
afterSeven
# Out:
#     systolic  diastolic    hr           date  glucosedata  when_eat  spo2  \
# 2      113.0       74.0  53.0  2023-07-24 15          130  식사 후 7시간    96
# 3      113.0       74.0  53.0  2023-07-24 15          130  식사 후 7시간    96
# 10     112.0       75.0  52.0  2023-07-24 15          130  식사 후 7시간    96
# 11     112.0       75.0  52.0  2023-07-24 15          130  식사 후 7시간    96
# 18     111.0       68.0  50.0  2023-07-24 15          130  식사 후 7시간    96
# 19     111.0       68.0  50.0  2023-07-24 15          130  식사 후 7시간    96
#
#     heart_rate_x  heart_rate_y
# 2             55            58
# 3             55            55
# 10            55            58
# 11            55            55
# 18            55            58
# 19            55            55

# %%
afterFour = mergedData.loc[mergedData['when_eat'] == '식사 후 4시간']
afterFour
# Out:
#     systolic  diastolic    hr           date  glucosedata  when_eat  spo2  \
# 6      113.0       74.0  53.0  2023-07-24 15          128  식사 후 4시간    96
# 7      113.0       74.0  53.0  2023-07-24 15          128  식사 후 4시간    96
# 14     112.0       75.0  52.0  2023-07-24 15          128  식사 후 4시간    96
# 15     112.0       75.0  52.0  2023-07-24 15          128  식사 후 4시간    96
# 22     111.0       68.0  50.0  2023-07-24 15          128  식사 후 4시간    96
# 23     111.0       68.0  50.0  2023-07-24 15          128  식사 후 4시간    96
# 24     106.0       76.0   NaN  2023-07-22 01          113  식사 후 4시간    94
# 26     128.0       78.0  63.0  2023-07-22 01          113  식사 후 4시간    94
# 28     134.0       86.0  64.0  2023-07-22 01          113  식사 후 4시간    94
# 30     123.0       82.0  62.0  2023-07-22 01          113  식사 후 4시간    94
# 32     137.0       89.0  65.0  2023-07-22 01          113  식사 후 4시간    94
# 34     133.0       83.0  61.0  2023-07-22 01          113  식사 후 4시간    94
# ...

# %%
afterThree = mergedData.loc[mergedData['when_eat'] == '식사 후 3시간']
afterThree
# Out:
#     systolic  diastolic    hr           date  glucosedata  when_eat  spo2  \
# 25     106.0       76.0   NaN  2023-07-22 01          118  식사 후 3시간    94
# 27     128.0       78.0  63.0  2023-07-22 01          118  식사 후 3시간    94
# 29     134.0       86.0  64.0  2023-07-22 01          118  식사 후 3시간    94
# 31     123.0       82.0  62.0  2023-07-22 01          118  식사 후 3시간    94
# 33     137.0       89.0  65.0  2023-07-22 01          118  식사 후 3시간    94
# 35     133.0       83.0  61.0  2023-07-22 01          118  식사 후 3시간    94
# 37     148.0       92.0  62.0  2023-07-22 01          118  식사 후 3시간    94
# 38     103.0       72.0   NaN  2023-07-19 19          111  식사 후 3시간    97
# 39     103.0       72.0   NaN  2023-07-19 19          111  식사 후 3시간    97
#
#     heart_rate_x  heart_rate_y
# 25            77            84
# 27            77            84
# 29            77            84
# 31            77            84
# 33            77            84
# 35            77            84
# ...

# %%
afterTwo = mergedData.loc[mergedData['when_eat'] == '식사 후 2시간']
afterTwo
# Out:
#      systolic  diastolic    hr           date  glucosedata  when_eat  spo2  \
# 101     126.0       79.0  72.0  2023-06-13 19          177  식사 후 2시간    96
# 103     133.0       79.0  71.0  2023-06-13 19          177  식사 후 2시간    96
#
#      heart_rate_x  heart_rate_y
# 101            74            73
# 103            74            73

# %%
mergedData = mergedData.drop(columns="heart_rate_y")
mergedData = mergedData.drop(columns="heart_rate_x")
#mergedData = mergedData.rename(columns={"heart_rate_x":"heart_rate"})

# %%
mergedData = mergedData.drop_duplicates()
mergedData
# Out:
#      systolic  diastolic    hr           date  glucosedata     when_eat  spo2
# 0       113.0       74.0  53.0  2023-07-24 15          131  공복 (8시간 이상)    96
# 2       113.0       74.0  53.0  2023-07-24 15          130     식사 후 7시간    96
# 4       113.0       74.0  53.0  2023-07-24 15          120  공복 (8시간 이상)    96
# 6       113.0       74.0  53.0  2023-07-24 15          128     식사 후 4시간    96
# 8       112.0       75.0  52.0  2023-07-24 15          131  공복 (8시간 이상)    96
# ..        ...        ...   ...            ...          ...          ...   ...
# 148     137.0       84.0   NaN  2023-04-21 16          165  공복 (8시간 이상)    94
# 149     118.0       83.0  76.0  2023-04-21 16          165  공복 (8시간 이상)    94
# 150     130.0       89.0  78.0  2023-04-21 16          165  공복 (8시간 이상)    94
# 151     121.0       77.0  71.0  2023-04-21 16          165  공복 (8시간 이상)    94
# 152     122.0       70.0  75.0  2023-04-21 16          165  공복 (8시간 이상)    94
#
# [96 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(mergedData.date, mergedData.spo2)
plt.xticks(rotation=90)
plt.xlabel('date')
plt.ylabel('spo2')
plt.show()

# %%
mergedData.loc[mergedData["date"]=="2023-04-21 16"]
# Out:
#      systolic  diastolic    hr           date  glucosedata     when_eat  spo2
# 148     137.0       84.0   NaN  2023-04-21 16          165  공복 (8시간 이상)    94
# 149     118.0       83.0  76.0  2023-04-21 16          165  공복 (8시간 이상)    94
# 150     130.0       89.0  78.0  2023-04-21 16          165  공복 (8시간 이상)    94
# 151     121.0       77.0  71.0  2023-04-21 16          165  공복 (8시간 이상)    94
# 152     122.0       70.0  75.0  2023-04-21 16          165  공복 (8시간 이상)    94

# %%
plt.bar(mergedData.date, mergedData.glucosedata)
plt.xticks(rotation=90)
plt.xlabel('date')
plt.ylabel('glucosedata')
plt.show()

# %%
plt.bar(mergedData.date, mergedData.systolic)
plt.xticks(rotation=90)
plt.xlabel('systolic')
plt.ylabel('heart_rate')
plt.show()

# %%
plt.bar(mergedData.date, mergedData.diastolic)
plt.xticks(rotation=90)
plt.xlabel('date')
plt.ylabel('diastolic')
plt.show()

# %%
plt.bar(mergedData.date, mergedData.hr)
plt.xticks(rotation=90)
plt.xlabel('date')
plt.ylabel('heart_rate')
plt.show()

# %%
mergedData.loc[mergedData["date"]=="2023-07-19 19"]
# Out:
#     systolic  diastolic  hr           date  glucosedata  when_eat  spo2
# 38     103.0       72.0 NaN  2023-07-19 19          111  식사 후 3시간    97

# %%
mergedData.loc[mergedData["date"]=="2023-06-20 20"]
# Out:
#     systolic  diastolic  hr           date  glucosedata  when_eat  spo2
# 96     122.0       83.0 NaN  2023-06-20 20          113  식사 후 4시간    94

# %%
mergedData.loc[mergedData["date"]=="2023-07-22 01"]
# Out:
#     systolic  diastolic    hr           date  glucosedata  when_eat  spo2
# 24     106.0       76.0   NaN  2023-07-22 01          113  식사 후 4시간    94
# 25     106.0       76.0   NaN  2023-07-22 01          118  식사 후 3시간    94
# 26     128.0       78.0  63.0  2023-07-22 01          113  식사 후 4시간    94
# 27     128.0       78.0  63.0  2023-07-22 01          118  식사 후 3시간    94
# 28     134.0       86.0  64.0  2023-07-22 01          113  식사 후 4시간    94
# 29     134.0       86.0  64.0  2023-07-22 01          118  식사 후 3시간    94
# 30     123.0       82.0  62.0  2023-07-22 01          113  식사 후 4시간    94
# 31     123.0       82.0  62.0  2023-07-22 01          118  식사 후 3시간    94
# 32     137.0       89.0  65.0  2023-07-22 01          113  식사 후 4시간    94
# 33     137.0       89.0  65.0  2023-07-22 01          118  식사 후 3시간    94
# 34     133.0       83.0  61.0  2023-07-22 01          113  식사 후 4시간    94
# 35     133.0       83.0  61.0  2023-07-22 01          118  식사 후 3시간    94
# ...
